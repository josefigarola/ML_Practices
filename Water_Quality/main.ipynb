# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

from sklearn.preprocessing import LabelEncoder,MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,ConfusionMatrixDisplay,confusion_matrix

from sklearn.linear_model import LogisticRegression

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("river-historical-1986_2020-en.csv")

# %%
df.head()
# Out:
#   Water Control Zone                  River Station       Dates  \
# 0           Junk Bay  Tseng Lan Shue Stream    JR11  29/04/1986
# 1           Junk Bay  Tseng Lan Shue Stream    JR11  19/05/1986
# 2           Junk Bay  Tseng Lan Shue Stream    JR11  18/06/1986
# 3           Junk Bay  Tseng Lan Shue Stream    JR11  24/07/1986
# 4           Junk Bay  Tseng Lan Shue Stream    JR11  15/08/1986
#
#    Water Temperature (°C)   pH  Conductivity (μS/cm)  Turbidity (NTU)  \
# 0                    25.0  6.9                 320.0              4.1
# 1                    26.6  7.1                 220.0              4.2
# 2                    28.4  7.2                 220.0              5.5
# 3                    26.5  7.3                 185.0              6.5
# 4                    30.1  7.3                 250.0              6.7
#
#    Dissolved Oxygen (mg/L) Total Solids (mg/L)  \
# 0                      6.0                 210
# 1                      5.3                 180
# ...

# %%
# Drop 1st and 2nd columns
df = df.drop(columns=["Water Control Zone","River", "Station", "Dates", "Unnamed: 12"], axis=1)
df.head()
# Out:
#    Water Temperature (°C)   pH  Conductivity (μS/cm)  Turbidity (NTU)  \
# 0                    25.0  6.9                 320.0              4.1
# 1                    26.6  7.1                 220.0              4.2
# 2                    28.4  7.2                 220.0              5.5
# 3                    26.5  7.3                 185.0              6.5
# 4                    30.1  7.3                 250.0              6.7
#
#    Dissolved Oxygen (mg/L) Total Solids (mg/L)  \
# 0                      6.0                 210
# 1                      5.3                 180
# 2                      6.2                 150
# 3                      5.2                  34
# 4                      5.1                 160
#
#   5-Day Biochemical Oxygen Demand (mg/L) Chemical Oxygen Demand (mg/L)
# 0                                    9.7                            13
# 1                                    5.6                            21
# ...

# %%
# Null values
df.isnull().sum()
# Out:
# Water Temperature (°C)                      9
# pH                                         12
# Conductivity (μS/cm)                        5
# Turbidity (NTU)                            16
# Dissolved Oxygen (mg/L)                     4
# Total Solids (mg/L)                       143
# 5-Day Biochemical Oxygen Demand (mg/L)    116
# Chemical Oxygen Demand (mg/L)              12
# dtype: int64

# %%
# Eliminar filas con valores nulos
df = df.dropna()

# Verificar la cantidad de valores nulos después de eliminar filas
print("Valores nulos después de eliminar filas:")
print(df.isnull().sum())
# Out:
# Valores nulos después de eliminar filas:
# Water Temperature (°C)                    0
# pH                                        0
# Conductivity (μS/cm)                      0
# Turbidity (NTU)                           0
# Dissolved Oxygen (mg/L)                   0
# Total Solids (mg/L)                       0
# 5-Day Biochemical Oxygen Demand (mg/L)    0
# Chemical Oxygen Demand (mg/L)             0
# dtype: int64

# %%
# Save clean dataset as csv
df.to_csv('river-historical.csv', index=False)
